# %% [markdown]
# # My Jupyter Notebook on IBM Watson Studio

# %% [markdown]
# __Leonardo Scarone__
# I´m currently an Economist.

# %% [markdown]
# *I´m interested in data science because I think it´s a field with a lot of potential and a great fit for me, because of my background and skills.*

# %% [markdown]
# ### The code below is supposed to do a simple math calculation

# %%
(1+7)/2
# Out:
# 4.0

# %% [markdown]
# ****
#
# - alpha
# - beta
# - gamma
#
# 1. alpha
# 2. beta
# 3. gamma
#
# https://es.wikipedia.org/wiki/IBM
#
# ![Foto%20cachorro.webp](attachment:Foto%20cachorro.webp)
